# %% [markdown]
# <a href="https://colab.research.google.com/github/ehsanrs2/cinematic.things.worlds/blob/main/3D_Photo_Inpainting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **[CVPR 2020] 3D Photography using Context-aware Layered Depth Inpainting**
#
# [project website](https://shihmengli.github.io/3D-Photo-Inpainting/)

# %% [markdown]
# - **Prepare environment**

# %%
# !pip3 install torch==1.4.0+cu100 torchvision==0.5.0+cu100 -f https://download.pytorch.org/whl/torch_stable.html
# !pip3 install opencv-python==4.2.0.32
# !pip3 install vispy==0.6.4
# !pip3 install moviepy==1.0.2
# !pip3 install transforms3d==0.3.1
# !pip3 install networkx==2.3
# !sudo apt install sed

# %% [markdown]
# - **Download script and pretrained model**

# %%
# %cd /content/
# !git clone https://github.com/vt-vl-lab/3d-photo-inpainting.git
# %cd 3d-photo-inpainting
# !sh download.sh

# %% [markdown]
# - **Switch off off-screen rendering**

# %%
# !sed -i 's/offscreen_rendering: True/offscreen_rendering: False/g' argument.yml

# %% [markdown]
# - **Please upload `.jpg` files to `/content/3d-photo-inpainting-master/image/`**
#   - You can run `Upload file` step multiple times to upload multiple `.jpg` files.
#   - You can remove the example files to upload your image files by mark the `Delete_Example`.

# %%
#@title Delete example(or old) files
Delete_Example = True #@param {type:"boolean"}
print(Delete_Example)
if Delete_Example == True:
  # !rm -r "/content/3d-photo-inpainting/image/"*
  # !rm -r "/content/3d-photo-inpainting/depth/"*
  # !rm -r "/content/3d-photo-inpainting/mesh/"*
  # !rm -r "/content/3d-photo-inpainting/video/"*
# Out:
# True

# %%
#@title Upload file
#@markdown -You can select multiple files.
# %cd image
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# %cd ..
# Out:
# /content/3d-photo-inpainting/image
#      <input type="file" id="files-7317cda9-399a-4677-b19e-5eb5ad844132" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7317cda9-399a-4677-b19e-5eb5ad844132">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving moon.jpg to moon.jpg
# User uploaded file "moon.jpg" with length 892340 bytes
# /content/3d-photo-inpainting

# %% [markdown]
# ---

# %% [markdown]
# - **Execute the 3D Photo Inpainting**
#   - Note: The 3D photo generation process usually takes about 2-3 minutes or more depending on the available computing resources.

# %%
# !python main.py --config argument.yml
# Out:
# running on device 0
#   0% 0/1 [00:00<?, ?it/s]Current Source ==>  moon
# Running depth extraction at 1632823880.7640162
# BoostingMonocularDepth/inputs/*.jpg
# BoostingMonocularDepth/outputs/*.png
# device: cuda
# Namespace(Final=True, R0=False, R20=False, colorize_results=False, data_dir='inputs/', depthNet=0, max_res=inf, net_receptive_field_size=None, output_dir='outputs', output_resolution=1, pix2pixsize=1024, savepatchs=0, savewholeest=0)
# ----------------- Options ---------------
#                     Final: True                          	[default: False]
#                        R0: False
#                       R20: False
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./pix2pix/checkpoints
#          colorize_results: False
#                 crop_size: 672
#                  data_dir: inputs/                       	[default: None]
#                  dataroot: None
#              dataset_mode: depthmerge
# ...

# %%
#@title Download results
#@markdown -By running this Cell you can download `depth` and `mesh` and `video` folders. 

#@markdown **The results are stored in the following directories**
#@markdown   - Corresponding depth map estimated by [MiDaS](https://github.com/intel-isl/MiDaS.git) 
#@markdown       - E.g. ```/content/3d-photo-inpainting/depth/moon.npy```
#@markdown   - Inpainted 3D mesh
#@markdown       - E.g. ```/content/3d-photo-inpainting/mesh/moon.ply```
#@markdown   - Rendered videos with zoom-in motion
#@markdown       - E.g. ```/content/3d-photo-inpainting/video/moon_zoom-in.mp4```
#@markdown  - Rendered videos with swing motion
#@markdown       - E.g. ```/content/3d-photo-inpainting/video/moon_swing.mp4```
#@markdown - Rendered videos with circle motion
#@markdown - E.g. ```/content/3d-photo-inpainting/video/moon_circle.mp4```
#@markdown ![](https://drive.google.com/uc?id=1xBiZAeGfhsoAsG08N5UM8-f993p0G5HF)
# !rm "/content/3d-photo-inpainting/download.zip"
# !zip -r download.zip "/content/3d-photo-inpainting/video" "/content/3d-photo-inpainting/depth" "/content/3d-photo-inpainting/mesh"  
files.download('download.zip')
